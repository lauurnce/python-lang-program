# %%
def mean(sample):
    return sum(sample) / len(sample)


mean([1, 2, 3, 4])

# %%
def add_one(x):
    # No return statement at all
    result = x + 1
    return result 


value = add_one(5)
value

print(value)
